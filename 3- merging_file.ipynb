# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('flat.csv')

# %%
df1 = pd.read_csv('house.csv')

# %%
df.fillna('NA',inplace=True)
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_12984\3404714331.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('NA',inplace=True)

# %%
df1.fillna('NA',inplace=True)
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_12984\3896716503.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df1.fillna('NA',inplace=True)

# %%
df.head()
# Out:
#    type  bhk sector                         society price price_sqft  \
# 0  flat  2.0     33          tulsiani easy in homes   0.4     6722.0
# 1  flat  2.0     61             smart world orchard  1.47    12250.0
# 2  flat  2.0     92                parkwood westend   0.7     5204.0
# 3  flat  2.0     36  signature global infinity mall  0.41     6269.0
# 4  flat  3.0    104                     ats triumph   1.8     7860.0
#
#   plot_area carpet_area build_area super_build_area bedroom bathroom balcony  \
# 0        NA       595.0         NA               NA     2.0      2.0     3.0
# 1        NA      1200.0         NA               NA     2.0      2.0     2.0
# 2        NA          NA     1345.0               NA     2.0      2.0     3.0
# 3        NA          NA         NA            654.0     2.0      2.0     3.0
# 4        NA      2290.0         NA               NA     3.0      4.0     3.0
#
#   facing flat_floor house_floor       agePossession  Servant Room  Store Room  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2850 entries, 0 to 2849
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              2850 non-null   object
#  1   bhk               2850 non-null   float64
#  2   sector            2850 non-null   object
#  3   society           2850 non-null   object
#  4   price             2850 non-null   object
#  5   price_sqft        2850 non-null   object
#  6   plot_area         2850 non-null   object
#  7   carpet_area       2850 non-null   object
#  8   build_area        2850 non-null   object
#  9   super_build_area  2850 non-null   object
#  10  bedroom           2850 non-null   object
#  11  bathroom          2850 non-null   object
#  12  balcony           2850 non-null   object
#  13  facing            2850 non-null   object
#  14  flat_floor        2850 non-null   object
#  15  house_floor       2850 non-null   object
# ...

# %%
df1.head()
# Out:
#     type  bhk sector           society price price_sqft plot_area carpet_area  \
# 0  house    5    70A  bptp visionnaire  5.25    20115.0    2610.0          NA
# 1  house   10     43       independent   2.1    38251.0     549.0          NA
# 2  house   21     54       independent   5.0    43066.0    1161.0          NA
# 3  house   12     43       independent   3.0    53763.0     558.0          NA
# 4  house   20     43       independent   4.5    39062.0    1152.0          NA
#
#   build_area super_build_area bedroom bathroom balcony      facing flat_floor  \
# 0         NA               NA     5.0      4.0     4.0  North-East         NA
# 1         NA               NA    10.0     10.0     4.0        West         NA
# 2         NA               NA    21.0     21.0     4.0       North         NA
# 3         NA               NA    12.0     12.0     4.0        West         NA
# 4         NA               NA    20.0     20.0     4.0        East         NA
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              936 non-null    object
#  1   bhk               936 non-null    int64
#  2   sector            936 non-null    object
#  3   society           936 non-null    object
#  4   price             936 non-null    object
#  5   price_sqft        936 non-null    object
#  6   plot_area         936 non-null    object
#  7   carpet_area       936 non-null    object
#  8   build_area        936 non-null    object
#  9   super_build_area  936 non-null    object
#  10  bedroom           936 non-null    object
#  11  bathroom          936 non-null    object
#  12  balcony           936 non-null    object
#  13  facing            936 non-null    object
#  14  flat_floor        936 non-null    object
#  15  house_floor       936 non-null    object
# ...

# %%
df2 = pd.concat([df,df1], ignore_index=False)

# %%
df2.head()
# Out:
#    type  bhk sector                         society price price_sqft  \
# 0  flat  2.0     33          tulsiani easy in homes   0.4     6722.0
# 1  flat  2.0     61             smart world orchard  1.47    12250.0
# 2  flat  2.0     92                parkwood westend   0.7     5204.0
# 3  flat  2.0     36  signature global infinity mall  0.41     6269.0
# 4  flat  3.0    104                     ats triumph   1.8     7860.0
#
#   plot_area carpet_area build_area super_build_area bedroom bathroom balcony  \
# 0        NA       595.0         NA               NA     2.0      2.0     3.0
# 1        NA      1200.0         NA               NA     2.0      2.0     2.0
# 2        NA          NA     1345.0               NA     2.0      2.0     3.0
# 3        NA          NA         NA            654.0     2.0      2.0     3.0
# 4        NA      2290.0         NA               NA     3.0      4.0     3.0
#
#   facing flat_floor house_floor       agePossession  Servant Room  Store Room  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3786 entries, 0 to 935
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              3786 non-null   object
#  1   bhk               3786 non-null   float64
#  2   sector            3786 non-null   object
#  3   society           3786 non-null   object
#  4   price             3786 non-null   object
#  5   price_sqft        3786 non-null   object
#  6   plot_area         3786 non-null   object
#  7   carpet_area       3786 non-null   object
#  8   build_area        3786 non-null   object
#  9   super_build_area  3786 non-null   object
#  10  bedroom           3786 non-null   object
#  11  bathroom          3786 non-null   object
#  12  balcony           3786 non-null   object
#  13  facing            3786 non-null   object
#  14  flat_floor        3786 non-null   object
#  15  house_floor       3786 non-null   object
# ...

# %%
df2.to_csv('flat-house.csv', index=False)
